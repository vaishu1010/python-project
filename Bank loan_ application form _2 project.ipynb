# %%
from tkinter import *
from tkinter.font import Font
from tkinter import ttk
import sqlite3
root=Tk()

my_font=Font(family="Helvetica",size=12)
my_font1=Font(family="Helvetica")
f=Frame(root)
f.grid()
f.configure(bg='antique white')
label56=Label(root,text="Application form for loan",bg='Red',fg='white',font=('Arial',30,'bold')).place(x=0,y=5)


def createnewwindow():
    newWindow=Toplevel(root)
    newWindow.title("Declaration form")
    newWindow.geometry("400x300")
    newWindow.config(bg='#9FD996')
    ttk.Label(newWindow,text="DECLARATION",font=my_font,relief=SUNKEN).place(x=50,y=20)
    t=ttk.Label(newWindow,text="I/We declare that all the particulars and information given in the application form are true\n,correct and they shall form the basis of any loan UBI may decide to grant me/us.I/We confirm that I/We have had no insolvency proceedings against me/us \n or have I/We ever been adjudicated insolvent and further confirm that\nI/We have read the brochure and understood the contents. I/We am/are aware that UBI may take up such references and make such enquiries in respect\n of this application as it may deem necessay. I/We undertake to inform UBI regarding any change in my/our occupation/employment\n and to provide any further information that you may require. I/We also undertake to authorise my/our \nemployer(s) to deduct Equated Monthly Installments from my/our salary and remit the same to UBI directly every month. UBI may make available any information\n contained in this form, other documents submitted to UBI and information pertaining to the loan to any institution or body. UBI may seek/receive information\n from any source/person to consider this application.I/We further agree that my/our loan shall be governed by rules of UBI which may be in force from time to time.",justify=LEFT)
    t.place(x=50,y=100)
    bt1=ttk.Button(newWindow,text="Submit",width=20,command=save_info).place(x=100,y=300)
    
def save_info():
    einfo=nameentry.get()
    einfo1=e1value.get()
    einfo12=e3value.get()
    einfo13=e4value.get()
    einfo14=e5value.get()
    einfo15=e6value.get()
    einfo16=var1.get()
    einfo18=var12.get()
    einfo20=var4.get()
    einfo22=e11value.get()
    einfo23=var23.get()
    einfo24=var24.get()
    einfo25=e91value.get()
    einfo26=present.get()
    einfo27=present1.get()
    einfo28=present2.get()
    einfo29=loan.get()
    einfo30=loan1.get()
    einfo31=loan.get()
    einfo32=e19value.get()
    einfo33=e23value.get()
    einfo34=var31.get()
    einfo35=var32.get()
    einfo36=var33.get()
    einfo37=var34.get()
    einfo38=e24value.get()
    einfo39=e25value.get()
    einfo40=e26value.get()
    print(f"""Name of the applicant is {einfo}\n
    his address is{einfo1} \n
    Pan card no is {einfo12} \n
    Monthly salary is {einfo13} \n
    number of years in occupation is {einfo14} years \n
    phone number is {einfo15} \n
    martial status is {einfo18}\n
    qualification is {einfo22}\n
    name of the bank is{einfo38}\n
    branch name is{einfo39}\n
    and the account number is {einfo40}""")


#def get_date():
#   ld.config(text=cal.get_date())


Label(root,text="Details",font=my_font,relief=SUNKEN,width=8).place(x=30,y=90)
    
nameentry=StringVar()
l1=Label(root,text="Name of the Applicant")
l1.place(x=10,y=120)
e=Entry(root,textvariable=nameentry).place(x=190,y=120)

e1value=StringVar()
l2=Label(root,text="Current Residential Address").place(x=10,y=150)
e1=Entry(root,textvariable=e1value).place(x=190,y=150)

#pan card no
e3value=StringVar()
l3=Label(root,text="Pan Card no.").place(x=550,y=120)
e3=Entry(root,textvariable=e3value).place(x=690,y=120)

#salary
e4value=IntVar()
l4=Label(root,text="Monthly salary").place(x=520,y=150)
e4=Entry(root,textvariable=e4value).place(x=690,y=150)
Label(root,text="Rs.").place(x=820,y=150)

#no of present occupation
e5value=IntVar()
l5=Label(root,text="No. of years in present \nOccupation").place(x=520,y=180)
e5=Entry(root,textvariable=e5value).place(x=690,y=180)

#phone no
e6value=IntVar()
l6=Label(root,text="Phone no.").place(x=520,y=220)
e6=Entry(root,textvariable=e6value).place(x=690,y=220)

#date of birth
#cal= Calendar(root, selectmode="day",year= 2021, month=3, day=3)
#cal.pack(pady=20)
#cal.place(x=540,y=270)


e13value=IntVar()
ld=Label(root,text="Date of Birth").place(x=520,y=250)
e3=Entry(root,textvariable=e13value).place(x=690,y=250)
#button= Button(root, text= "Select the Date", command=get_date)
#button.place(x=560,y=460)


#sex
l7=Label(root,text="Sex").place(x=10,y=170)
var1=IntVar()

Radiobutton(root,text="Male",variable=var1,value=1).place(x=180,y=170)
Radiobutton(root,text="Female",padx=10,variable=var1,value=2).place(x=250,y=170)
Radiobutton(root,text="others",padx=15,variable=var1,value=3).place(x=330,y=170)

#marital status
l8=Label(root,text="Martial status").place(x=10,y=190)
var12=IntVar()
Radiobutton(root,text="Single",variable=var12,value=1).place(x=180,y=190)
Radiobutton(root,text="Married",padx=10,variable=var12,value=2).place(x=250,y=190)

#status
l9=Label(root,text="Status").place(x=10,y=230)
var4=IntVar()
Radiobutton(root,text="Resident",variable=var4,value=1).place(x=180,y=230)
Radiobutton(root,text="Non-Resident",padx=10,variable=var4,value=2).place(x=220,y=230)

#no of dependants
l10=Label(root,text="No. of Dependants").place(x=10,y=260)
t=Label(root,text="Children").place(x=150,y=260)
w=Spinbox(root,from_=0,to=10,width=5)
w.place(x=220,y=260)
t1=Label(root,text="Others").place(x=300,y=260)
y=Spinbox(root,from_=0,to=10,width=5)
y.place(x=350,y=260)

#Qualifications
e11value=StringVar()
l11=Label(root,text="Qualifications").place(x=10,y=290)
e11=Entry(root,textvariable=e11value).place(x=190,y=290)

#occupation
l12=Label(root,text="Occupation").place(x=10,y=310)
var23=IntVar()
var24=IntVar()
Radiobutton(root,text="Self-Employed",variable=var23,value=1).place(x=220,y=310)
Radiobutton(root,text="Employed",padx=10,variable=var24,value=2).place(x=290,y=310)

#Employer
e91value=StringVar()
l13=Label(root,text="Employer/Bussiness").place(x=10,y=330)
e13=Entry(root,textvariable=e91value).place(x=190,y=330)


#status of present accomodation
l16=Label(root,text="Status of present \n accomodation").place(x=10,y=370)
present=IntVar()
present1=IntVar()
present2=IntVar()
service=Checkbutton(root,text="Own",variable=present).place(x=170,y=370)
service1=Checkbutton(root,text="Rented",variable=present1).place(x=240,y=370)
service2=Checkbutton(root,text="Family",variable=present2).place(x=310,y=370)

#loan request
l17=Label(root,text="LOAN REQUESTED",font=my_font,relief=SUNKEN,width=20).place(x=30,y=430)

#Type of loan
l18=Label(root,text="Type of loan").place(x=10,y=460)
loan=IntVar()
loan1=IntVar()
loan2=IntVar()
sal=Checkbutton(root,text="Home Loan",variable=loan).place(x=180,y=460)
sal1=Checkbutton(root,text="Home Extension",variable=loan1).place(x=285,y=460)
sal2=Checkbutton(root,text="Home Improvement",variable=loan2).place(x=390,y=460)

#monthly expenditure
e19value=IntVar()
l19=Label(root,text="Your monthly expenditure").place(x=10,y=490)
e19=Entry(root,textvariable=e19value).place(x=180,y=490)

#Loan details
l20=Label(root,text="LOAN DETAILS",font=my_font,relief=SUNKEN,width=20).place(x=30,y=520)
l21=Label(root,text="Purpose of Loan").place(x=10,y=550)

var31 = IntVar()
Checkbutton(root, text='Construction', variable=var31).place(x=180,y=550)
var32 = IntVar()
Checkbutton(root, text='Purchase', variable=var32).place(x=180,y=570)
var33 = IntVar()
Checkbutton(root, text='Extension', variable=var33).place(x=180,y=590)
var34 = IntVar()
Checkbutton(root, text='Improvement', variable=var34).place(x=180,y=620)

#Banking account details
e23value=StringVar()
l22=Label(root,text="ACCOUNT DETAILS",font=my_font,relief=SUNKEN,width=20).place(x=980,y=100)
l23=Label(root,text="Name of the \nAccount Holder").place(x=850,y=130)
e23=Entry(root,textvariable=e23value).place(x=1000,y=130)

e24value=StringVar()
l24=Label(root,text="Name of the bank").place(x=850,y=160)
e24=Entry(root,textvariable=e24value).place(x=1000,y=160)

e25value=StringVar()
l25=Label(root,text="Branch Name").place(x=850,y=190)
e25=Entry(root,textvariable=e25value).place(x=1000,y=190)

e26value=IntVar()
l26=Label(root,text="Account Number").place(x=850,y=230)
e26=Entry(root,textvariable=e26value).place(x=1000,y=230)



b1=Button(root,text="Next Page",command=createnewwindow).place(x=1000,y=500)


root.geometry('500x400')
root.title("Application Form")
root.resizable(True,True)
root.mainloop()
