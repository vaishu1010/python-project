# %%
# loan application form

# %%
from tkinter import *
from tkinter.font import Font
from tkinter import messagebox as msg
#from Page2 import *
#import customtkinter
#customtkinter.set_appearance_mode("System")
#def nextbutton():
#    print("You clicked next button")
#    root.destroy()
#    import Page2
def printinfo():
    print(f"{e.get(),e1.get(),e2.get(),e3.get(),e4.get(),e5.get(),e6.get(),e7.get(),e8.get(),e9.get(),e10.get(),e11.get()}")
    with open("C:\\Users\\pc\\Downloads\\newproject\\etails.txt","a") as sd:
        sd.write(f"My name is {e.get(),e1.get(),e2.get(),e3.get(),e4.get(),e5.get(),e6.get(),e7.get(),e8.get(),e9.get(),e10.get(),e11.get()}\n")
        submit=msg.askquestion("Confirm", "Are you sure you want to submit?")
        if submit=='yes':
            msg1='Application Submitted Successfully.'
        else:
            msg1='Please make necessary changes.'
        msg.showinfo('Submit',msg1)
        Button(f,text='logout',font="Helvtica 12 bold",bg='SeaGreen1',command=root.destroy,activeforeground='green3',padx=4,pady=1).grid(row=22,column=2)

def createnewwindow():
    newWindow=Toplevel(root)
    newWindow.title("Declaration form")
    newWindow.geometry("200x100")
    Label(newWindow,text="DECLARATION",font=my_font,relief=SUNKEN).place(x=50,y=20)
    t=Label(newWindow,text="I/We declare that all the particulars and information given in the application form are true\n,correct and they shall form the basis of any loan UBI may decide to grant me/us.I/We confirm that I/We have had no insolvency proceedings against me/us \n or have I/We ever been adjudicated insolvent and further confirm that\nI/We have read the brochure and understood the contents. I/We am/are aware that UBI may take up such references and make such enquiries in respect\n of this application as it may deem necessay. I/We undertake to inform UBI regarding any change in my/our occupation/employment\n and to provide any further information that you may require. I/We also undertake to authorise my/our \nemployer(s) to deduct Equated Monthly Installments from my/our salary and remit the same to UBI directly every month. UBI may make available any information\n contained in this form, other documents submitted to UBI and information pertaining to the loan to any institution or body. UBI may seek/receive information\n from any source/person to consider this application.I/We further agree that my/our loan shall be governed by rules of UBI which may be in force from time to time.",justify=LEFT)
    t.place(x=50,y=100)
    bt=Button(newWindow,text="Submit",width=20).place(x=50,y=300)


root=Tk()

root.geometry("600x500")
#f1=Frame(root,width=250,height=20,bg="red").grid(row=0,column=5)
my_font=Font(family="Helvetica",size=12)
f=Frame(root)
f.grid()
f.configure(bg='antique white')
#Label
Label(root,text="Loan Application Form",font="ariel 20 bold",bg="red",fg="white").place(x=100,y=9)



#personal and employment details
l2=Label(root,text="PERSONAL AND EMPLOYMENT DETAILS",font=my_font,relief='sunken')
l2.place(x=30,y=50)

#name of the applicant
l3=Label(root,text="Name of the Applicant")
l3.place(x=10,y=80)
e=Entry(root).place(x=190,y=80)

#current residential address
l4=Label(root,text="Current Residential Address").place(x=10,y=100)
e1=Entry(root).place(x=190,y=100)

#pan card no
l11=Label(root,text="Pan Card no.").place(x=520,y=120)
e4=Entry(root).place(x=620,y=120)

#salary
l14=Label(root,text="Monthly salary").place(x=520,y=150)
e7=Entry(root).place(x=620,y=150)
Label(root,text="Rs.").place(x=730,y=150)

#no of present occupation
l15=Label(root,text="No. of years in present \nOccupation").place(x=520,y=190)
e8=Entry(root).place(x=650,y=190)

#phone no
l5=Label(root,text="Phone no.").place(x=520,y=70)
e2=Entry(root).place(x=620,y=70)

#date of birth
l6=Label(root,text="Date of Birth").place(x=520,y=90)
e3=Entry(root).place(x=620,y=90)

#sex
l7=Label(root,text="Sex").place(x=10,y=120)
var=IntVar()
Radiobutton(root,text="Male",variable=var,value=1).place(x=180,y=120)
Radiobutton(root,text="Female",padx=10,variable=var,value=2).place(x=250,y=120)
Radiobutton(root,text="others",padx=15,variable=var,value=3).place(x=330,y=120)

#marital status
l8=Label(root,text="Martial status").place(x=10,y=150)
var1=IntVar()
Radiobutton(root,text="Single",variable=var1,value=1).place(x=180,y=150)
Radiobutton(root,text="Married",padx=10,variable=var1,value=2).place(x=250,y=150)

#status
l9=Label(root,text="Status").place(x=10,y=170)
var1=IntVar()
Radiobutton(root,text="Resident",variable=var1,value=1).place(x=180,y=170)
Radiobutton(root,text="Non-Resident",padx=10,variable=var1,value=2).place(x=220,y=170)

#no of dependants
l10=Label(root,text="No. of Dependants").place(x=10,y=200)
t=Label(root,text="Children").place(x=150,y=200)
w=Spinbox(root,from_=0,to=10,width=5)
w.place(x=220,y=200)
t1=Label(root,text="Others").place(x=300,y=200)
y=Spinbox(root,from_=0,to=10,width=5)
y.place(x=350,y=200)

#Qualifications
l11=Label(root,text="Qualifications").place(x=10,y=220)
e5=Entry(root).place(x=190,y=220)

#occupation
l12=Label(root,text="Occupation").place(x=10,y=240)
var2=IntVar()
Radiobutton(root,text="Self-Employed",variable=var2,value=1).place(x=220,y=240)
Radiobutton(root,text="Employed",padx=10,variable=var2,value=2).place(x=290,y=240)

#Employer
l13=Label(root,text="Employer/Bussiness").place(x=10,y=270)
e6=Entry(root).place(x=190,y=270)


#status of present accomodation
l16=Label(root,text="Status of present \n accomodation").place(x=10,y=290)
present=IntVar()
present1=IntVar()
present2=IntVar()
service=Checkbutton(root,text="Own",variable=present).place(x=170,y=290)
service1=Checkbutton(root,text="Rented",variable=present1).place(x=240,y=290)
service2=Checkbutton(root,text="Family",variable=present2).place(x=310,y=290)

#loan request
l17=Label(root,text="LOAN REQUESTED",font=my_font,relief=SUNKEN).place(x=30,y=340)

#Type of loan
l18=Label(root,text="Type of loan").place(x=10,y=370)
loan=IntVar()
loan1=IntVar()
loan2=IntVar()
sal=Checkbutton(root,text="Home Loan",variable=loan).place(x=180,y=370)
sal1=Checkbutton(root,text="Home Extension",variable=loan1).place(x=285,y=370)
sal2=Checkbutton(root,text="Home Improvement",variable=loan2).place(x=390,y=370)

#monthly expenditure
l19=Label(root,text="Your monthly expenditure").place(x=10,y=400)
e7=Entry(root).place(x=180,y=400)

#Loan details
l20=Label(root,text="LOAN DETAILS",font=my_font,relief=SUNKEN).place(x=30,y=430)
l21=Label(root,text="Purpose of Loan").place(x=10,y=460)

var1 = IntVar()
Checkbutton(root, text='Construction', variable=var1).place(x=180,y=460)
var2 = IntVar()
Checkbutton(root, text='Purchase', variable=var2).place(x=180,y=480)
var3 = IntVar()
Checkbutton(root, text='Extension', variable=var3).place(x=180,y=500)
var4 = IntVar()
Checkbutton(root, text='Improvement', variable=var4).place(x=180,y=520)

#Banking account details

l22=Label(root,text="ACCOUNT DETAILS",font=my_font,relief=SUNKEN).place(x=980,y=50)
l23=Label(root,text="Name of the \nAccount Holder").place(x=850,y=100)
e8=Entry(root).place(x=1000,y=100)

l24=Label(root,text="Name of the bank").place(x=850,y=150)
e9=Entry(root).place(x=1000,y=150)
l25=Label(root,text="Branch Name").place(x=850,y=180)
e10=Entry(root).place(x=1000,y=180)

l26=Label(root,text="Account Number").place(x=850,y=210)
e11=Entry(root).place(x=1000,y=210)

b=Button(root,text="Submit",command=printinfo,width=30).place(x=900,y=500)
b1=Button(root,text="Next Page",command=createnewwindow).place(x=1000,y=550)
#button=customtkinter.CTkButton(master=root,
 #                             command=Nextbutton,text="Next",fg_color=("dodger blue","dodger blue"))
#button.place(x=1000,y=500)
root.mainloop()
